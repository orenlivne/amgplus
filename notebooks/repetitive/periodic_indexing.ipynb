# %% [markdown]
# ## Periodic Indexing Sandbox

# %%
# %run /Users/olivne/helmholtz/src/helmholtz/startup.ipy

# %%
L = 3.5
x = np.linspace(0, L)
f = lambda x: (x + 0.5 * L) % L - 0.5 * L

# %%
plt.plot(x, f(x))
